# %% [markdown]
# <a href="https://colab.research.google.com/github/emamarela/ActiveLearning/blob/main/DistilRoBERT_MultiEurlex_DE_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/webis-de/small-text
# Out:
# Cloning into 'small-text'...
# remote: Enumerating objects: 2025, done.
# remote: Counting objects: 100% (2025/2025), done.
# remote: Compressing objects: 100% (1342/1342), done.
# remote: Total 2025 (delta 1317), reused 1377 (delta 669), pack-reused 0
# Receiving objects: 100% (2025/2025), 400.73 KiB | 11.45 MiB/s, done.
# Resolving deltas: 100% (1317/1317), done.

# %%
# !pip install transformers
# !pip install numpy==1.20.0
# !pip install datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.16.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.20.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.47)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: numpy==1.20.0 in /usr/local/lib/python3.7/dist-packages (1.20.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (1.18.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.20.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.4.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.10.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.4.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.11)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
import sys
sys.path.insert(0, '/content/small-text/')
sys.path.insert(0, '/content/small-text/examples')

# %%
import logging

import numpy as np
from datasets import load_dataset
from transformers import AutoTokenizer

from small_text.active_learner import PoolBasedActiveLearner
from small_text.initialization import random_initialization_stratified
from small_text.integrations.transformers import TransformerModelArguments
from small_text.integrations.transformers.classifiers.factories import TransformerBasedClassificationFactory
from small_text.query_strategies import PoolExhaustedException, EmptyPoolException
from small_text.query_strategies import RandomSampling, LeastConfidence, EmbeddingKMeans

from examplecode.data.example_data_multilabel import get_train_test
from examplecode.data.example_data_transformers import preprocess_data
from examplecode.shared import evaluate_multi_label

TRANSFORMER_MODEL = TransformerModelArguments('distilbert-base-german-cased')  #distilbert-base-german-cased

# %%
TRANSFORMER_MODEL = TransformerModelArguments('distilroberta-base')

num_classes = 21
clf_factory = TransformerBasedClassificationFactory(TRANSFORMER_MODEL,
                                                    num_classes,
                                                    kwargs=dict({
                                                        'device': 'cuda',
                                                        'multi_label': True
                                                    }))
query_strategy = EmbeddingKMeans()

tokenizer = AutoTokenizer.from_pretrained(TRANSFORMER_MODEL.model, cache_dir='.cache/')
# Out:
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
results = []

def perform_active_learning(active_learner, train, labeled_indices, test):
    # Perform 10 iterations of active learning...
    for i in range(10):
        # ...where each iteration consists of labelling 20 samples
        q_indices = active_learner.query(num_samples=20)

        # Simulate user interaction here. Replace this for real-world usage.
        y = train.y[q_indices]

        # Return the labels for the current query to the active learner.
        active_learner.update(y)

        labeled_indices = np.concatenate([q_indices, labeled_indices])

        print('Iteration #{:d} ({} samples)'.format(i, len(labeled_indices)))
        evaluate_multi_label(active_learner, train[labeled_indices], test)
        results.append(evaluate_multi_label(active_learner, train[labeled_indices], test))

# %%
def initialize_active_learner(active_learner, y_train):

    x_indices_initial = random_initialization_stratified(y_train, n_samples=400)
    y_initial = y_train[x_indices_initial]

    active_learner.initialize_data(x_indices_initial, y_initial)

    return x_indices_initial

# %%
eurlex_de = load_dataset('multi_eurlex', 'de')
# Out:
# Reusing dataset multi_eurlex (/root/.cache/huggingface/datasets/multi_eurlex/de/1.0.0/8ec8b79877a517369a143ead6679d1788d13e51cf641ed29772f4449e8364fb6)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
def main():
    # Active learning parameters
    num_classes = 21
    clf_factory = TransformerBasedClassificationFactory(TRANSFORMER_MODEL,
                                                        num_classes,
                                                        kwargs=dict({
                                                            'device': 'cuda',
                                                            'multi_label': True
                                                        }))
    query_strategy = EmbeddingKMeans()

    # Prepare some data
    #train, test = get_train_test()
    train = eurlex_de['train']
    test = eurlex_de['validation']
    tokenizer = AutoTokenizer.from_pretrained(TRANSFORMER_MODEL.model, cache_dir='.cache/')
    x_train = preprocess_data(tokenizer, train['text'], train['labels'], multi_label=True)
    x_test = preprocess_data(tokenizer, test['text'], test['labels'], multi_label=True)
    # Active learner
    active_learner = PoolBasedActiveLearner(clf_factory, query_strategy, x_train)
    
    
    labeled_indices = initialize_active_learner(active_learner, x_train.y)
    print(6)

    try:
        perform_active_learning(active_learner, x_train, labeled_indices, x_test)
    except PoolExhaustedException:
        print('Error! Not enough samples left to handle the query.')
    except EmptyPoolException:
        print('Error! No more samples left. (Unlabeled pool is empty)')

# %%
if __name__ == '__main__':
    logging.getLogger('small_text').setLevel(logging.INFO)

    main()
# Out:
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0399(train)	|	Acc: 83.9%(train)
# 	Loss: 0.0364(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0284(train)	|	Acc: 87.3%(train)
# 	Loss: 0.0328(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0264(train)	|	Acc: 87.2%(train)
# 	Loss: 0.0322(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0257(train)	|	Acc: 87.6%(train)
# 	Loss: 0.0318(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0254(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0318(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0250(train)	|	Acc: 87.8%(train)
# 	Loss: 0.0316(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0246(train)	|	Acc: 88.5%(train)
# 	Loss: 0.0315(valid)	|	Acc: 87.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0242(train)	|	Acc: 89.0%(train)
# 	Loss: 0.0312(valid)	|	Acc: 88.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0239(train)	|	Acc: 89.2%(train)
# 	Loss: 0.0315(valid)	|	Acc: 88.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:10
# 	Train Set Size: 360
# 	Loss: 0.0238(train)	|	Acc: 89.2%(train)
# 	Loss: 0.0314(valid)	|	Acc: 88.2%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 8 (valid_loss=0.031169)
# 6
# 100%|██████████| 55000/55000 [08:38<00:00, 106.02it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0419(train)	|	Acc: 84.0%(train)
# 	Loss: 0.0355(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0295(train)	|	Acc: 87.3%(train)
# 	Loss: 0.0321(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0273(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0310(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0267(train)	|	Acc: 87.3%(train)
# 	Loss: 0.0305(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0261(train)	|	Acc: 87.4%(train)
# 	Loss: 0.0303(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0257(train)	|	Acc: 87.4%(train)
# 	Loss: 0.0301(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0255(train)	|	Acc: 87.7%(train)
# 	Loss: 0.0298(valid)	|	Acc: 87.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0251(train)	|	Acc: 88.5%(train)
# 	Loss: 0.0292(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0247(train)	|	Acc: 89.0%(train)
# 	Loss: 0.0291(valid)	|	Acc: 87.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:11
# 	Train Set Size: 378
# 	Loss: 0.0243(train)	|	Acc: 89.2%(train)
# 	Loss: 0.0289(valid)	|	Acc: 88.0%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.028918)
# Iteration #0 (420 samples)
# Train accuracy: 0.55
# Test accuracy: 0.43
# ---
# Train accuracy: 0.55
# Test accuracy: 0.43
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.04it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0416(train)	|	Acc: 82.6%(train)
# 	Loss: 0.0339(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0291(train)	|	Acc: 87.2%(train)
# 	Loss: 0.0304(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0269(train)	|	Acc: 87.3%(train)
# 	Loss: 0.0293(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0262(train)	|	Acc: 87.3%(train)
# 	Loss: 0.0290(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0258(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0288(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0255(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0286(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0252(train)	|	Acc: 87.9%(train)
# 	Loss: 0.0280(valid)	|	Acc: 87.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0246(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0275(valid)	|	Acc: 88.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0240(train)	|	Acc: 89.4%(train)
# 	Loss: 0.0274(valid)	|	Acc: 88.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:11
# 	Train Set Size: 396
# 	Loss: 0.0237(train)	|	Acc: 89.6%(train)
# 	Loss: 0.0273(valid)	|	Acc: 88.4%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.027305)
# Iteration #1 (440 samples)
# Train accuracy: 0.56
# Test accuracy: 0.41
# ---
# Train accuracy: 0.56
# Test accuracy: 0.41
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.03it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0423(train)	|	Acc: 80.7%(train)
# 	Loss: 0.0320(valid)	|	Acc: 86.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0291(train)	|	Acc: 87.1%(train)
# 	Loss: 0.0291(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0272(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0282(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0267(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0279(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0262(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0279(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0263(train)	|	Acc: 87.1%(train)
# 	Loss: 0.0278(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0260(train)	|	Acc: 87.1%(train)
# 	Loss: 0.0276(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0258(train)	|	Acc: 87.1%(train)
# 	Loss: 0.0276(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0255(train)	|	Acc: 87.4%(train)
# 	Loss: 0.0273(valid)	|	Acc: 87.1%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:12
# 	Train Set Size: 414
# 	Loss: 0.0254(train)	|	Acc: 87.8%(train)
# 	Loss: 0.0271(valid)	|	Acc: 87.1%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.027089)
# Iteration #2 (460 samples)
# Train accuracy: 0.49
# Test accuracy: 0.39
# ---
# Train accuracy: 0.49
# Test accuracy: 0.39
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.08it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:13
# 	Train Set Size: 432
# 	Loss: 0.0393(train)	|	Acc: 84.2%(train)
# 	Loss: 0.0290(valid)	|	Acc: 86.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0285(train)	|	Acc: 86.8%(train)
# 	Loss: 0.0267(valid)	|	Acc: 86.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0270(train)	|	Acc: 86.7%(train)
# 	Loss: 0.0260(valid)	|	Acc: 86.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0265(train)	|	Acc: 86.7%(train)
# 	Loss: 0.0256(valid)	|	Acc: 86.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0261(train)	|	Acc: 87.0%(train)
# 	Loss: 0.0253(valid)	|	Acc: 87.1%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0257(train)	|	Acc: 87.8%(train)
# 	Loss: 0.0245(valid)	|	Acc: 87.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0248(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0239(valid)	|	Acc: 88.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0243(train)	|	Acc: 89.1%(train)
# 	Loss: 0.0235(valid)	|	Acc: 89.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0239(train)	|	Acc: 89.3%(train)
# 	Loss: 0.0233(valid)	|	Acc: 88.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:12
# 	Train Set Size: 432
# 	Loss: 0.0236(train)	|	Acc: 89.6%(train)
# 	Loss: 0.0231(valid)	|	Acc: 89.2%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.023080)
# Iteration #3 (480 samples)
# Train accuracy: 0.54
# Test accuracy: 0.38
# ---
# Train accuracy: 0.54
# Test accuracy: 0.38
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.08it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0407(train)	|	Acc: 80.8%(train)
# 	Loss: 0.0358(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0290(train)	|	Acc: 86.7%(train)
# 	Loss: 0.0331(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0273(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0324(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0268(train)	|	Acc: 86.7%(train)
# 	Loss: 0.0323(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0264(train)	|	Acc: 86.8%(train)
# 	Loss: 0.0317(valid)	|	Acc: 86.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0261(train)	|	Acc: 87.6%(train)
# 	Loss: 0.0310(valid)	|	Acc: 88.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0254(train)	|	Acc: 88.3%(train)
# 	Loss: 0.0304(valid)	|	Acc: 88.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0248(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0299(valid)	|	Acc: 88.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0244(train)	|	Acc: 89.1%(train)
# 	Loss: 0.0298(valid)	|	Acc: 88.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:13
# 	Train Set Size: 450
# 	Loss: 0.0242(train)	|	Acc: 89.2%(train)
# 	Loss: 0.0297(valid)	|	Acc: 88.8%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.029694)
# Iteration #4 (500 samples)
# Train accuracy: 0.53
# Test accuracy: 0.38
# ---
# Train accuracy: 0.53
# Test accuracy: 0.38
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.04it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0409(train)	|	Acc: 80.9%(train)
# 	Loss: 0.0356(valid)	|	Acc: 85.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:13
# 	Train Set Size: 468
# 	Loss: 0.0288(train)	|	Acc: 86.6%(train)
# 	Loss: 0.0326(valid)	|	Acc: 85.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:13
# 	Train Set Size: 468
# 	Loss: 0.0271(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0318(valid)	|	Acc: 85.3%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0266(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0314(valid)	|	Acc: 85.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0263(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0312(valid)	|	Acc: 85.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0261(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0310(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:13
# 	Train Set Size: 468
# 	Loss: 0.0258(train)	|	Acc: 87.6%(train)
# 	Loss: 0.0305(valid)	|	Acc: 86.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0253(train)	|	Acc: 88.0%(train)
# 	Loss: 0.0298(valid)	|	Acc: 87.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:14
# 	Train Set Size: 468
# 	Loss: 0.0249(train)	|	Acc: 88.5%(train)
# 	Loss: 0.0295(valid)	|	Acc: 87.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:13
# 	Train Set Size: 468
# 	Loss: 0.0247(train)	|	Acc: 88.6%(train)
# 	Loss: 0.0294(valid)	|	Acc: 87.5%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.029444)
# Iteration #5 (520 samples)
# Train accuracy: 0.50
# Test accuracy: 0.40
# ---
# Train accuracy: 0.50
# Test accuracy: 0.40
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.04it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0398(train)	|	Acc: 82.7%(train)
# 	Loss: 0.0320(valid)	|	Acc: 86.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0290(train)	|	Acc: 86.4%(train)
# 	Loss: 0.0295(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0275(train)	|	Acc: 86.6%(train)
# 	Loss: 0.0285(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0271(train)	|	Acc: 86.6%(train)
# 	Loss: 0.0282(valid)	|	Acc: 86.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0266(train)	|	Acc: 86.9%(train)
# 	Loss: 0.0275(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0261(train)	|	Acc: 87.8%(train)
# 	Loss: 0.0276(valid)	|	Acc: 87.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0253(train)	|	Acc: 88.6%(train)
# 	Loss: 0.0261(valid)	|	Acc: 89.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0248(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0256(valid)	|	Acc: 90.1%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0243(train)	|	Acc: 89.2%(train)
# 	Loss: 0.0254(valid)	|	Acc: 90.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:14
# 	Train Set Size: 486
# 	Loss: 0.0240(train)	|	Acc: 89.3%(train)
# 	Loss: 0.0253(valid)	|	Acc: 90.7%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.025288)
# Iteration #6 (540 samples)
# Train accuracy: 0.57
# Test accuracy: 0.39
# ---
# Train accuracy: 0.57
# Test accuracy: 0.39
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.04it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0388(train)	|	Acc: 83.0%(train)
# 	Loss: 0.0313(valid)	|	Acc: 87.1%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0283(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0292(valid)	|	Acc: 85.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0270(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0286(valid)	|	Acc: 86.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0265(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0283(valid)	|	Acc: 87.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0264(train)	|	Acc: 87.0%(train)
# 	Loss: 0.0280(valid)	|	Acc: 86.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0259(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0270(valid)	|	Acc: 88.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0253(train)	|	Acc: 88.1%(train)
# 	Loss: 0.0263(valid)	|	Acc: 88.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0246(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0264(valid)	|	Acc: 88.7%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0244(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0259(valid)	|	Acc: 88.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:15
# 	Train Set Size: 504
# 	Loss: 0.0241(train)	|	Acc: 88.9%(train)
# 	Loss: 0.0257(valid)	|	Acc: 88.8%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.025734)
# Iteration #7 (560 samples)
# Train accuracy: 0.53
# Test accuracy: 0.40
# ---
# Train accuracy: 0.53
# Test accuracy: 0.40
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.06it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0388(train)	|	Acc: 83.9%(train)
# 	Loss: 0.0295(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0289(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0272(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0274(train)	|	Acc: 86.5%(train)
# 	Loss: 0.0263(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0268(train)	|	Acc: 86.8%(train)
# 	Loss: 0.0259(valid)	|	Acc: 87.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0264(train)	|	Acc: 87.5%(train)
# 	Loss: 0.0250(valid)	|	Acc: 88.4%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0256(train)	|	Acc: 88.1%(train)
# 	Loss: 0.0244(valid)	|	Acc: 89.0%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0252(train)	|	Acc: 88.5%(train)
# 	Loss: 0.0240(valid)	|	Acc: 89.1%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0248(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0238(valid)	|	Acc: 89.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0244(train)	|	Acc: 88.9%(train)
# 	Loss: 0.0235(valid)	|	Acc: 89.2%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:15
# 	Train Set Size: 522
# 	Loss: 0.0243(train)	|	Acc: 88.9%(train)
# 	Loss: 0.0234(valid)	|	Acc: 89.2%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 10 (valid_loss=0.023396)
# Iteration #8 (580 samples)
# Train accuracy: 0.52
# Test accuracy: 0.40
# ---
# Train accuracy: 0.52
# Test accuracy: 0.40
# ---
# 100%|██████████| 55000/55000 [08:38<00:00, 106.05it/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:small_text.integrations.transformers.classifiers.classification:Overridering scheduler since optimizer in kwargs needs to be passed in combination with scheduler
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 1 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0389(train)	|	Acc: 81.4%(train)
# 	Loss: 0.0296(valid)	|	Acc: 85.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 2 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0279(train)	|	Acc: 86.4%(train)
# 	Loss: 0.0280(valid)	|	Acc: 85.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 3 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0268(train)	|	Acc: 86.7%(train)
# 	Loss: 0.0275(valid)	|	Acc: 85.6%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 4 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0262(train)	|	Acc: 87.1%(train)
# 	Loss: 0.0263(valid)	|	Acc: 88.3%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 5 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0255(train)	|	Acc: 88.2%(train)
# 	Loss: 0.0253(valid)	|	Acc: 88.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 6 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0250(train)	|	Acc: 88.3%(train)
# 	Loss: 0.0248(valid)	|	Acc: 88.5%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 7 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0245(train)	|	Acc: 88.4%(train)
# 	Loss: 0.0244(valid)	|	Acc: 88.9%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 8 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0241(train)	|	Acc: 88.8%(train)
# 	Loss: 0.0239(valid)	|	Acc: 89.3%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 9 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0237(train)	|	Acc: 89.1%(train)
# 	Loss: 0.0237(valid)	|	Acc: 89.8%(valid)
# INFO:small_text.integrations.transformers.classifiers.classification:Epoch: 10 | 00:00:16
# 	Train Set Size: 540
# 	Loss: 0.0235(train)	|	Acc: 89.3%(train)
# 	Loss: 0.0238(valid)	|	Acc: 89.6%(valid)
# INFO:small_text.integrations.pytorch.model_selection:Using model 9 (valid_loss=0.023670)
# Iteration #9 (600 samples)
# Train accuracy: 0.56
# Test accuracy: 0.31
# ---
# Train accuracy: 0.56
# Test accuracy: 0.31
# ---
